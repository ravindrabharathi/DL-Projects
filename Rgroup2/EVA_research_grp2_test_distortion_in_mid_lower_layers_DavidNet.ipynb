# %% [markdown]
# <a href="https://colab.research.google.com/github/ravindrabharathi/Project1/blob/master/Rgroup2/EVA_research_grp2_test_distortion_in_mid_lower_layers_DavidNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Choose tf2 backend on colab

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# Install TensorFlow
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
# Out:
# TensorFlow 2.x selected.

# %% [markdown]
# ### Install tf_utils

# %%
# !pip install --upgrade git+https://github.com/ravindrabharathi/tf_utils
# Out:
# Collecting git+https://github.com/ravindrabharathi/tf_utils
#   Cloning https://github.com/ravindrabharathi/tf_utils to /tmp/pip-req-build-4mmu0oms
#   Running command git clone -q https://github.com/ravindrabharathi/tf_utils /tmp/pip-req-build-4mmu0oms
# Building wheels for collected packages: tf-utils
#   Building wheel for tf-utils (setup.py) ... done
#   Created wheel for tf-utils: filename=tf_utils-0.1-cp36-none-any.whl size=8427 sha256=23eb6c42df282e8a09fdf97a0a24c77f94c1ec7b14504e2884710e52d728f0cb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-y45ytqdx/wheels/95/af/bb/690b94c65a5aad47a5c39e75f158a2b043448e908c5c121791
# Successfully built tf-utils
# Installing collected packages: tf-utils
# Successfully installed tf-utils-0.1

# %% [markdown]
# ### import the data module

# %%
import tf_utils.data as ds
# Out:
# Finished 'get_cpu_num' in 0.0000 secs

# %% [markdown]
# ### set batch size

# %%
batch_size=512
ds.batch_size=batch_size
EPOCHS=24

# %% [markdown]
# ### downlaod data and create tf records

# %%
ds.get_cifar10_and_create_tfrecords()
# Out:
# HBox(children=(IntProgress(value=0, description='cifar-10-python.tar.gz', max=170498071, style=ProgressStyle(d…
# Finished 'download_file' in 12.6174 secs
# Finished 'download_cifar10_files' in 12.6181 secs
# Done
# Finished 'extract_cifar10_files' in 1.8893 secs
# Finished '_get_file_names' in 0.0000 secs
# Generating ./train.tfrecords
# Finished 'read_pickle_from_file' in 0.1609 secs
# Finished 'read_pickle_from_file' in 0.1478 secs
# Finished 'read_pickle_from_file' in 0.1481 secs
# Finished 'read_pickle_from_file' in 0.1457 secs
# Finished 'read_pickle_from_file' in 0.1478 secs
# Finished 'convert_to_tfrecord' in 3.2250 secs
# Done!
# Generating ./eval.tfrecords
# Finished 'read_pickle_from_file' in 0.1453 secs
# Finished 'convert_to_tfrecord' in 0.6544 secs
# Done!
# Finished 'create_tf_records' in 3.8809 secs
# Finished 'get_cifar10_and_create_tfrecords' in 18.3887 secs

# %% [markdown]
# ### create train and test dataset

# %%
train_ds1=ds.get_train_ds(batch_size=batch_size,shuffle=True,distort=True)
train_ds2=ds.get_train_ds(batch_size=batch_size,shuffle=True,distort=False)

test_ds=ds.get_eval_ds(batch_size=batch_size)
# Out:
# WARNING:tensorflow:Entity <function parse_batch_distort at 0x7f689e61df28> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function parse_batch_distort at 0x7f689e61df28> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# distorting image
# Finished 'get_tf_dataset' in 5.3933 secs
# Finished 'get_tf_dataset_in_batches' in 5.3936 secs
# Finished 'get_train_ds' in 5.3938 secs
# WARNING:tensorflow:Entity <function parse_batch at 0x7f689e61dea0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function parse_batch at 0x7f689e61dea0> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# Finished 'get_tf_dataset' in 0.1379 secs
# Finished 'get_tf_dataset_in_batches' in 0.1381 secs
# Finished 'get_train_ds' in 0.1382 secs
# Finished 'get_tf_dataset' in 0.0313 secs
# Finished 'get_tf_dataset_in_batches' in 0.0315 secs
# Finished 'get_eval_ds' in 0.0317 secs

# %% [markdown]
# ### import visualization module

# %%
import tf_utils.visualize as vz

# %% [markdown]
# ### plot images from train dataset1 , train dataset by default uses image augmenttation of cutout,flip-left-right,random-pad-crop

# %%
vz.plot_cifar10_files(train_ds1)

# %%
vz.plot_cifar10_files(train_ds2)

# %% [markdown]
# ### Training - Build model , compile and train

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GlobalAveragePooling2D,  Activation, GlobalMaxPooling2D
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization , Dense, Lambda

from tensorflow.keras.optimizers import Adam,SGD

import numpy as np
import math
WEIGHT_DECAY=1.25e-4
reg=tf.keras.regularizers.l2(WEIGHT_DECAY)
def init_pytorch(shape, dtype=tf.float32, partition_info=None):
  fan = np.prod(shape[:-1])
  bound = 1 / math.sqrt(fan)
  return tf.random.uniform(shape, minval=-bound, maxval=bound, dtype=dtype)

def conv(inp,f=32,k=3):
  conv_layer=Conv2D(f,k,use_bias=False,padding='same',kernel_initializer=init_pytorch, kernel_regularizer=reg)(inp)
  conv_layer=BatchNormalization(momentum=0.9, epsilon=1e-5)(conv_layer)
  conv_layer=Activation('relu')(conv_layer)
  return conv_layer
def resBlk(inp,f=32,k=3,residual=True) :
  res1=conv(inp,f,k)
  res1=MaxPooling2D(pool_size=(2,2))(res1)
  if residual:
    res2=conv(res1,f,k)
    res3=conv(res2,f,k)
    return res1+res3
  else:
    return res1  

def apply_weight(x):
  return x*0.125  

def random_pad_crop(image,padding=2):
  shp=tf.shape(image)
  
  image=tf.pad(image,[(0, 0), (padding, padding), (padding, padding), (0, 0)], mode='reflect')
  
  image=tf.image.random_crop(image,size=shp)
  return image  

def flip_left_right(image):
  return tf.image.random_flip_left_right(image)    

def aug1(image):
  print('is_training',is_training)
  if is_training:
    return ds.cutout(ds.random_pad_crop(image,padding=2),100,size=4)
    #return flip_left_right(random_pad_crop(image))
  else:
    print('inside validation cycle\n===============\n')
    return image  

def aug2(image):
  print('is_training',is_training)
  if is_training:
    return ds.cutout(ds.random_pad_crop(image,padding=1),100,size=2)
    #return flip_left_right(random_pad_crop(image))
  else:
    print('inside validation cycle\n===============\n')
    return image

# %%
def build_model(distort_param=0):
  f=64
  inp=Input(shape=(32,32,3))
  layer1=conv(inp,f,3)
  res1=resBlk(layer1,f*2,3)
  if (distort_param in [1,3,4]):
    res1=Lambda(aug1)(res1)
  res2=resBlk(res1,f*4,3,False)
  if (distort_param in [2,3,5]):
    res2=Lambda(aug2)(res2)
  res3=resBlk(res2,f*8,3)
  
  layer2=GlobalMaxPooling2D()(res3)
  layer3=Dense(10, kernel_initializer=init_pytorch, use_bias=False,kernel_regularizer=reg)(layer2)
  layer4=Lambda(lambda x: x*0.125)(layer3)
  out=Activation('softmax')(layer4)
  model=Model(inputs=[inp],outputs=[out])
  model.summary()
  return model

# %%
from tensorflow.keras.callbacks import LearningRateScheduler

def lr_schedule():
    
    def schedule(epoch):

      lr=lr1=np.interp([epoch],[0, 5,24], [0.025, 0.4, 0])[0]
      print('epoch ', epoch+1, ': setting learning rate to ',lr1)
      return lr
    
    return LearningRateScheduler(schedule)

lr_sched = lr_schedule()

# %%
for model_params in [0,1,2,3,4,5]:
  is_training=True
  #global_step = tf.train.get_or_create_global_step()
  model=model=build_model(model_params)
  opt=SGD(lr=0.025,momentum=0.9,nesterov=True)
  model.compile(loss='categorical_crossentropy',
              optimizer=opt,metrics=['accuracy']
              )
  batch_size=512
  
  if model_params in [0,4,5]:
    train_ds=train_ds1
    print('Model will be trained with image augmentation in put layer\n====================')
    if model_params==4:
      print('Model will also include distortion after Res Blk 1\n=======================')
    elif model_params==5:
      print('Model will also include distortion after Res Blk 2\n=======================')
      
  else:
    if model_params==1:
      print('Model will be trained with distortion after Res Blk 1\n=======================')
    elif model_params==2:
      print('Model will be trained with distortion after Res Blk 2\n=======================')
    elif model_params==3:
      print('Model will be trained with distortion after Res Blk 1 and Res Blk 2\n=======================')    
    train_ds=train_ds2  
  model.fit(train_ds,epochs=EPOCHS, steps_per_epoch=np.ceil(50000/batch_size), 
          callbacks=[lr_sched],
          verbose=1)
  is_training=False
  score=model.evaluate(test_ds, steps =np.ceil(10000/batch_size), verbose=1)

  del(model)
  del(train_ds)
  
  print('val accuracy score at the end of training model type ',model_params, score)
  print("=========================================\n")

#validation_data=test_ds, validation_steps=np.ceil(10000/batch_size),
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   1728        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 128)  73728       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 128)  512         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 128)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 128)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 128)  147456      max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16, 16, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 128)  147456      activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add (TensorFlowOpLa [(None, 16, 16, 128) 0           max_pooling2d[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 256)  294912      tf_op_layer_add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 256)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 256)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 512)    1179648     max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 512)    2048        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 8, 8, 512)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 4, 4, 512)    0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 4, 4, 512)    2359296     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 4, 4, 512)    2048        conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 4, 4, 512)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 4, 4, 512)    2359296     activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 512)    2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 4, 4, 512)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_1 (TensorFlowOp [(None, 4, 4, 512)]  0           max_pooling2d_2[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d (GlobalMax (None, 512)          0           tf_op_layer_add_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           5120        global_max_pooling2d[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 10)           0           dense[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 10)           0           lambda[0][0]
# ==================================================================================================
# Total params: 6,577,600
# Trainable params: 6,573,120
# Non-trainable params: 4,480
# __________________________________________________________________________________________________
# Model will be trained with image augmentation in put layer
# ====================
# Train for 98.0 steps
# epoch  1 : setting learning rate to  0.025
# Epoch 1/24
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f68452aa598> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f68452aa598> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# 98/98 [==============================] - 55s 564ms/step - loss: 1.6693 - accuracy: 0.4276
# epoch  2 : setting learning rate to  0.1
# Epoch 2/24
# 98/98 [==============================] - 44s 447ms/step - loss: 1.2695 - accuracy: 0.5816
# epoch  3 : setting learning rate to  0.175
# Epoch 3/24
# 98/98 [==============================] - 44s 447ms/step - loss: 0.9681 - accuracy: 0.6958
# epoch  4 : setting learning rate to  0.24999999999999997
# Epoch 4/24
# 98/98 [==============================] - 44s 447ms/step - loss: 0.8582 - accuracy: 0.7459
# epoch  5 : setting learning rate to  0.325
# Epoch 5/24
# 98/98 [==============================] - 44s 447ms/step - loss: 0.8088 - accuracy: 0.7733
# epoch  6 : setting learning rate to  0.4
# Epoch 6/24
# 98/98 [==============================] - 44s 449ms/step - loss: 0.7772 - accuracy: 0.7960
# epoch  7 : setting learning rate to  0.37894736842105264
# Epoch 7/24
# 98/98 [==============================] - 44s 448ms/step - loss: 0.6871 - accuracy: 0.8295
# epoch  8 : setting learning rate to  0.35789473684210527
# Epoch 8/24
# 98/98 [==============================] - 44s 448ms/step - loss: 0.6355 - accuracy: 0.8506
# epoch  9 : setting learning rate to  0.33684210526315794
# Epoch 9/24
# 98/98 [==============================] - 44s 446ms/step - loss: 0.6007 - accuracy: 0.8652
# epoch  10 : setting learning rate to  0.31578947368421056
# Epoch 10/24
# 98/98 [==============================] - 44s 448ms/step - loss: 0.5682 - accuracy: 0.8777
# epoch  11 : setting learning rate to  0.2947368421052632
# Epoch 11/24
# 98/98 [==============================] - 44s 446ms/step - loss: 0.5391 - accuracy: 0.8883
# epoch  12 : setting learning rate to  0.2736842105263158
# Epoch 12/24
# 98/98 [==============================] - 44s 449ms/step - loss: 0.5168 - accuracy: 0.8964
# epoch  13 : setting learning rate to  0.25263157894736843
# Epoch 13/24
# 98/98 [==============================] - 44s 449ms/step - loss: 0.4940 - accuracy: 0.9049
# epoch  14 : setting learning rate to  0.23157894736842108
# Epoch 14/24
# 98/98 [==============================] - 44s 449ms/step - loss: 0.4754 - accuracy: 0.9096
# epoch  15 : setting learning rate to  0.2105263157894737
# Epoch 15/24
# 98/98 [==============================] - 44s 447ms/step - loss: 0.4592 - accuracy: 0.9145
# epoch  16 : setting learning rate to  0.18947368421052635
# Epoch 16/24
# 98/98 [==============================] - 44s 448ms/step - loss: 0.4323 - accuracy: 0.9237
# epoch  17 : setting learning rate to  0.16842105263157897
# Epoch 17/24
# 98/98 [==============================] - 44s 447ms/step - loss: 0.4122 - accuracy: 0.9301
# epoch  18 : setting learning rate to  0.1473684210526316
# Epoch 18/24
# 98/98 [==============================] - 44s 445ms/step - loss: 0.3863 - accuracy: 0.9383
# epoch  19 : setting learning rate to  0.12631578947368421
# Epoch 19/24
# 98/98 [==============================] - 44s 447ms/step - loss: 0.3673 - accuracy: 0.9428
# epoch  20 : setting learning rate to  0.10526315789473689
# Epoch 20/24
# 98/98 [==============================] - 44s 449ms/step - loss: 0.3436 - accuracy: 0.9501
# epoch  21 : setting learning rate to  0.08421052631578951
# Epoch 21/24
# 98/98 [==============================] - 44s 447ms/step - loss: 0.3162 - accuracy: 0.9591
# epoch  22 : setting learning rate to  0.06315789473684214
# Epoch 22/24
# 98/98 [==============================] - 44s 445ms/step - loss: 0.2959 - accuracy: 0.9650
# epoch  23 : setting learning rate to  0.04210526315789476
# Epoch 23/24
# 98/98 [==============================] - 44s 445ms/step - loss: 0.2793 - accuracy: 0.9702
# epoch  24 : setting learning rate to  0.02105263157894738
# Epoch 24/24
# 98/98 [==============================] - 44s 447ms/step - loss: 0.2608 - accuracy: 0.9769
# 20/20 [==============================] - 3s 131ms/step - loss: 0.3897 - accuracy: 0.9331
# val accuracy score at the end of training model type  0 [0.3897462129592896, 0.93310547]
# =========================================
#
# is_training True
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   1728        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 128)  73728       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 128)  147456      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 128)  512         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16, 16, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  147456      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 128)  512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16, 16, 128)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_2 (TensorFlowOp [(None, 16, 16, 128) 0           max_pooling2d_3[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 16, 16, 128)  0           tf_op_layer_add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 256)  294912      lambda_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16, 16, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 256)    0           activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 512)    1179648     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 512)    2048        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 8, 8, 512)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 4, 4, 512)    0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 4, 4, 512)    2359296     max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 4, 4, 512)    2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4, 4, 512)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 512)    2359296     activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, 4, 512)    2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4, 4, 512)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_3 (TensorFlowOp [(None, 4, 4, 512)]  0           max_pooling2d_5[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 512)          0           tf_op_layer_add_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           5120        global_max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 10)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 10)           0           lambda_2[0][0]
# ==================================================================================================
# Total params: 6,577,600
# Trainable params: 6,573,120
# Non-trainable params: 4,480
# __________________________________________________________________________________________________
# Model will be trained with distortion after Res Blk 1
# =======================
# Train for 98.0 steps
# epoch  1 : setting learning rate to  0.025
# Epoch 1/24
# is_training True
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f68427e8620> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f68427e8620> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# is_training True
# 98/98 [==============================] - 49s 495ms/step - loss: 1.5983 - accuracy: 0.4579
# epoch  2 : setting learning rate to  0.1
# Epoch 2/24
# 98/98 [==============================] - 46s 468ms/step - loss: 1.1827 - accuracy: 0.6120
# epoch  3 : setting learning rate to  0.175
# Epoch 3/24
# 98/98 [==============================] - 46s 469ms/step - loss: 0.8726 - accuracy: 0.7317
# epoch  4 : setting learning rate to  0.24999999999999997
# Epoch 4/24
# 98/98 [==============================] - 46s 469ms/step - loss: 0.7607 - accuracy: 0.7806
# epoch  5 : setting learning rate to  0.325
# Epoch 5/24
# 98/98 [==============================] - 46s 469ms/step - loss: 0.6743 - accuracy: 0.8199
# epoch  6 : setting learning rate to  0.4
# Epoch 6/24
# 98/98 [==============================] - 46s 468ms/step - loss: 0.6666 - accuracy: 0.8300
# epoch  7 : setting learning rate to  0.37894736842105264
# Epoch 7/24
# 98/98 [==============================] - 46s 468ms/step - loss: 0.5711 - accuracy: 0.8702
# epoch  8 : setting learning rate to  0.35789473684210527
# Epoch 8/24
# 98/98 [==============================] - 46s 467ms/step - loss: 0.5080 - accuracy: 0.8952
# epoch  9 : setting learning rate to  0.33684210526315794
# Epoch 9/24
# 98/98 [==============================] - 46s 469ms/step - loss: 0.4693 - accuracy: 0.9091
# epoch  10 : setting learning rate to  0.31578947368421056
# Epoch 10/24
# 98/98 [==============================] - 46s 467ms/step - loss: 0.4261 - accuracy: 0.9260
# epoch  11 : setting learning rate to  0.2947368421052632
# Epoch 11/24
# 98/98 [==============================] - 46s 469ms/step - loss: 0.4001 - accuracy: 0.9350
# epoch  12 : setting learning rate to  0.2736842105263158
# Epoch 12/24
# 98/98 [==============================] - 46s 469ms/step - loss: 0.3714 - accuracy: 0.9453
# epoch  13 : setting learning rate to  0.25263157894736843
# Epoch 13/24
# 98/98 [==============================] - 46s 468ms/step - loss: 0.3481 - accuracy: 0.9542
# epoch  14 : setting learning rate to  0.23157894736842108
# Epoch 14/24
# 98/98 [==============================] - 46s 468ms/step - loss: 0.3188 - accuracy: 0.9634
# epoch  15 : setting learning rate to  0.2105263157894737
# Epoch 15/24
# 98/98 [==============================] - 46s 469ms/step - loss: 0.2944 - accuracy: 0.9699
# epoch  16 : setting learning rate to  0.18947368421052635
# Epoch 16/24
# 98/98 [==============================] - 46s 468ms/step - loss: 0.2686 - accuracy: 0.9780
# epoch  17 : setting learning rate to  0.16842105263157897
# Epoch 17/24
# 98/98 [==============================] - 46s 468ms/step - loss: 0.2499 - accuracy: 0.9824
# epoch  18 : setting learning rate to  0.1473684210526316
# Epoch 18/24
# 98/98 [==============================] - 46s 468ms/step - loss: 0.2327 - accuracy: 0.9872
# epoch  19 : setting learning rate to  0.12631578947368421
# Epoch 19/24
# 98/98 [==============================] - 46s 468ms/step - loss: 0.2106 - accuracy: 0.9921
# epoch  20 : setting learning rate to  0.10526315789473689
# Epoch 20/24
# 98/98 [==============================] - 46s 468ms/step - loss: 0.1961 - accuracy: 0.9946
# epoch  21 : setting learning rate to  0.08421052631578951
# Epoch 21/24
# 98/98 [==============================] - 46s 468ms/step - loss: 0.1841 - accuracy: 0.9964
# epoch  22 : setting learning rate to  0.06315789473684214
# Epoch 22/24
# 98/98 [==============================] - 46s 467ms/step - loss: 0.1732 - accuracy: 0.9981
# epoch  23 : setting learning rate to  0.04210526315789476
# Epoch 23/24
# 98/98 [==============================] - 46s 468ms/step - loss: 0.1667 - accuracy: 0.9989
# epoch  24 : setting learning rate to  0.02105263157894738
# Epoch 24/24
# 98/98 [==============================] - 46s 469ms/step - loss: 0.1628 - accuracy: 0.9993
# is_training False
# inside validation cycle
# ===============
#
# 20/20 [==============================] - 3s 135ms/step - loss: 0.4518 - accuracy: 0.9177
# val accuracy score at the end of training model type  1 [0.4518249467015266, 0.9176758]
# =========================================
#
# is_training True
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 64)   1728        input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 32, 32, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 32, 32, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 128)  73728       activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 32, 32, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 128)  0           activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 128)  147456      max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 16, 16, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 128)  147456      activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 128)  512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 16, 16, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_4 (TensorFlowOp [(None, 16, 16, 128) 0           max_pooling2d_6[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 16, 16, 256)  294912      tf_op_layer_add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 16, 256)  1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 16, 16, 256)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 256)    0           activation_22[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 8, 8, 256)    0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 512)    1179648     lambda_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 8, 8, 512)    2048        conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 8, 8, 512)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 4, 4, 512)    0           activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 4, 4, 512)    2359296     max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 4, 4, 512)    2048        conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 4, 4, 512)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 4, 4, 512)    2359296     activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 4, 4, 512)    2048        conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 4, 4, 512)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_5 (TensorFlowOp [(None, 4, 4, 512)]  0           max_pooling2d_8[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_2 (GlobalM (None, 512)          0           tf_op_layer_add_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           5120        global_max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 10)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 10)           0           lambda_4[0][0]
# ==================================================================================================
# Total params: 6,577,600
# Trainable params: 6,573,120
# Non-trainable params: 4,480
# __________________________________________________________________________________________________
# Model will be trained with distortion after Res Blk 2
# =======================
# Train for 98.0 steps
# epoch  1 : setting learning rate to  0.025
# Epoch 1/24
# is_training True
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f6841c13598> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f6841c13598> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# is_training True
# 98/98 [==============================] - 47s 484ms/step - loss: 1.5892 - accuracy: 0.4586
# epoch  2 : setting learning rate to  0.1
# Epoch 2/24
# 98/98 [==============================] - 45s 458ms/step - loss: 1.1285 - accuracy: 0.6324
# epoch  3 : setting learning rate to  0.175
# Epoch 3/24
# 98/98 [==============================] - 45s 458ms/step - loss: 0.8236 - accuracy: 0.7503
# epoch  4 : setting learning rate to  0.24999999999999997
# Epoch 4/24
# 98/98 [==============================] - 45s 458ms/step - loss: 0.7266 - accuracy: 0.7949
# epoch  5 : setting learning rate to  0.325
# Epoch 5/24
# 98/98 [==============================] - 45s 458ms/step - loss: 0.6671 - accuracy: 0.8250
# epoch  6 : setting learning rate to  0.4
# Epoch 6/24
# 98/98 [==============================] - 45s 457ms/step - loss: 0.6274 - accuracy: 0.8460
# epoch  7 : setting learning rate to  0.37894736842105264
# Epoch 7/24
# 98/98 [==============================] - 45s 457ms/step - loss: 0.5281 - accuracy: 0.8868
# epoch  8 : setting learning rate to  0.35789473684210527
# Epoch 8/24
# 98/98 [==============================] - 45s 458ms/step - loss: 0.4675 - accuracy: 0.9101
# epoch  9 : setting learning rate to  0.33684210526315794
# Epoch 9/24
# 98/98 [==============================] - 45s 457ms/step - loss: 0.4229 - accuracy: 0.9275
# epoch  10 : setting learning rate to  0.31578947368421056
# Epoch 10/24
# 98/98 [==============================] - 45s 458ms/step - loss: 0.3903 - accuracy: 0.9393
# epoch  11 : setting learning rate to  0.2947368421052632
# Epoch 11/24
# 98/98 [==============================] - 45s 458ms/step - loss: 0.3569 - accuracy: 0.9530
# epoch  12 : setting learning rate to  0.2736842105263158
# Epoch 12/24
# 98/98 [==============================] - 45s 458ms/step - loss: 0.3296 - accuracy: 0.9611
# epoch  13 : setting learning rate to  0.25263157894736843
# Epoch 13/24
# 98/98 [==============================] - 45s 457ms/step - loss: 0.3045 - accuracy: 0.9695
# epoch  14 : setting learning rate to  0.23157894736842108
# Epoch 14/24
# 98/98 [==============================] - 45s 457ms/step - loss: 0.2823 - accuracy: 0.9763
# epoch  15 : setting learning rate to  0.2105263157894737
# Epoch 15/24
# 98/98 [==============================] - 45s 458ms/step - loss: 0.2615 - accuracy: 0.9820
# epoch  16 : setting learning rate to  0.18947368421052635
# Epoch 16/24
# 98/98 [==============================] - 45s 458ms/step - loss: 0.2404 - accuracy: 0.9866
# epoch  17 : setting learning rate to  0.16842105263157897
# Epoch 17/24
# 98/98 [==============================] - 45s 457ms/step - loss: 0.2205 - accuracy: 0.9910
# epoch  18 : setting learning rate to  0.1473684210526316
# Epoch 18/24
# 98/98 [==============================] - 45s 458ms/step - loss: 0.2007 - accuracy: 0.9946
# epoch  19 : setting learning rate to  0.12631578947368421
# Epoch 19/24
# 98/98 [==============================] - 45s 457ms/step - loss: 0.1895 - accuracy: 0.9955
# epoch  20 : setting learning rate to  0.10526315789473689
# Epoch 20/24
# 98/98 [==============================] - 45s 457ms/step - loss: 0.1753 - accuracy: 0.9977
# epoch  21 : setting learning rate to  0.08421052631578951
# Epoch 21/24
# 98/98 [==============================] - 45s 457ms/step - loss: 0.1643 - accuracy: 0.9989
# epoch  22 : setting learning rate to  0.06315789473684214
# Epoch 22/24
# 98/98 [==============================] - 45s 458ms/step - loss: 0.1587 - accuracy: 0.9990
# epoch  23 : setting learning rate to  0.04210526315789476
# Epoch 23/24
# 98/98 [==============================] - 45s 458ms/step - loss: 0.1527 - accuracy: 0.9996
# epoch  24 : setting learning rate to  0.02105263157894738
# Epoch 24/24
# 98/98 [==============================] - 45s 458ms/step - loss: 0.1503 - accuracy: 0.9995
# is_training False
# inside validation cycle
# ===============
#
# 20/20 [==============================] - 3s 132ms/step - loss: 0.4826 - accuracy: 0.9104
# val accuracy score at the end of training model type  2 [0.4826087146997452, 0.9104492]
# =========================================
#
# is_training True
# is_training True
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 64)   1728        input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 32, 32, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 32, 32, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 128)  73728       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 32, 32, 128)  512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 32, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 16, 16, 128)  0           activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 128)  147456      max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 16, 16, 128)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 128)  147456      activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 16, 16, 128)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_6 (TensorFlowOp [(None, 16, 16, 128) 0           max_pooling2d_9[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 16, 16, 128)  0           tf_op_layer_add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 256)  294912      lambda_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 256)  1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 16, 16, 256)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 8, 8, 256)    0           activation_31[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 8, 8, 256)    0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 512)    1179648     lambda_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 8, 512)    2048        conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 8, 8, 512)    0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 4, 4, 512)    0           activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 4, 4, 512)    2359296     max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 4, 4, 512)    2048        conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 4, 4, 512)    0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 4, 4, 512)    2359296     activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 4, 4, 512)    2048        conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 4, 4, 512)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_7 (TensorFlowOp [(None, 4, 4, 512)]  0           max_pooling2d_11[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_3 (GlobalM (None, 512)          0           tf_op_layer_add_7[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           5120        global_max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 10)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 10)           0           lambda_7[0][0]
# ==================================================================================================
# Total params: 6,577,600
# Trainable params: 6,573,120
# Non-trainable params: 4,480
# __________________________________________________________________________________________________
# Model will be trained with distortion after Res Blk 1 and Res Blk 2
# =======================
# Train for 98.0 steps
# epoch  1 : setting learning rate to  0.025
# Epoch 1/24
# is_training True
# is_training True
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f68411606a8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f68411606a8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# is_training True
# is_training True
# 98/98 [==============================] - 50s 512ms/step - loss: 1.6607 - accuracy: 0.4331
# epoch  2 : setting learning rate to  0.1
# Epoch 2/24
# 98/98 [==============================] - 47s 480ms/step - loss: 1.2034 - accuracy: 0.6042
# epoch  3 : setting learning rate to  0.175
# Epoch 3/24
# 98/98 [==============================] - 47s 481ms/step - loss: 0.9375 - accuracy: 0.7085
# epoch  4 : setting learning rate to  0.24999999999999997
# Epoch 4/24
# 98/98 [==============================] - 47s 480ms/step - loss: 0.8201 - accuracy: 0.7590
# epoch  5 : setting learning rate to  0.325
# Epoch 5/24
# 98/98 [==============================] - 47s 480ms/step - loss: 0.7569 - accuracy: 0.7902
# epoch  6 : setting learning rate to  0.4
# Epoch 6/24
# 98/98 [==============================] - 47s 479ms/step - loss: 0.7321 - accuracy: 0.8088
# epoch  7 : setting learning rate to  0.37894736842105264
# Epoch 7/24
# 98/98 [==============================] - 47s 480ms/step - loss: 0.6539 - accuracy: 0.8409
# epoch  8 : setting learning rate to  0.35789473684210527
# Epoch 8/24
# 98/98 [==============================] - 47s 480ms/step - loss: 0.5931 - accuracy: 0.8645
# epoch  9 : setting learning rate to  0.33684210526315794
# Epoch 9/24
# 98/98 [==============================] - 47s 479ms/step - loss: 0.5494 - accuracy: 0.8825
# epoch  10 : setting learning rate to  0.31578947368421056
# Epoch 10/24
# 98/98 [==============================] - 47s 480ms/step - loss: 0.5079 - accuracy: 0.8971
# epoch  11 : setting learning rate to  0.2947368421052632
# Epoch 11/24
# 98/98 [==============================] - 47s 481ms/step - loss: 0.4750 - accuracy: 0.9098
# epoch  12 : setting learning rate to  0.2736842105263158
# Epoch 12/24
# 98/98 [==============================] - 47s 482ms/step - loss: 0.4512 - accuracy: 0.9175
# ...
# epoch  6 : setting learning rate to  0.4
# Epoch 6/24
# 98/98 [==============================] - 46s 472ms/step - loss: 0.8741 - accuracy: 0.7557
# epoch  7 : setting learning rate to  0.37894736842105264
# Epoch 7/24
# 98/98 [==============================] - 46s 470ms/step - loss: 0.7732 - accuracy: 0.7957
# epoch  8 : setting learning rate to  0.35789473684210527
# Epoch 8/24
# 98/98 [==============================] - 46s 470ms/step - loss: 0.7288 - accuracy: 0.8159
# epoch  9 : setting learning rate to  0.33684210526315794
# Epoch 9/24
# 98/98 [==============================] - 46s 470ms/step - loss: 0.6800 - accuracy: 0.8338
# epoch  10 : setting learning rate to  0.31578947368421056
# Epoch 10/24
# 98/98 [==============================] - 46s 470ms/step - loss: 0.6528 - accuracy: 0.8457
# epoch  11 : setting learning rate to  0.2947368421052632
# Epoch 11/24
# 98/98 [==============================] - 46s 470ms/step - loss: 0.6233 - accuracy: 0.8576
# epoch  12 : setting learning rate to  0.2736842105263158
# Epoch 12/24
# 98/98 [==============================] - 47s 475ms/step - loss: 0.5937 - accuracy: 0.8659
# epoch  13 : setting learning rate to  0.25263157894736843
# Epoch 13/24
# 98/98 [==============================] - 46s 471ms/step - loss: 0.5753 - accuracy: 0.8740
# epoch  14 : setting learning rate to  0.23157894736842108
# Epoch 14/24
# 98/98 [==============================] - 46s 470ms/step - loss: 0.5487 - accuracy: 0.8822
# epoch  15 : setting learning rate to  0.2105263157894737
# Epoch 15/24
# 98/98 [==============================] - 46s 470ms/step - loss: 0.5267 - accuracy: 0.8892
# epoch  16 : setting learning rate to  0.18947368421052635
# Epoch 16/24
# 98/98 [==============================] - 46s 471ms/step - loss: 0.4991 - accuracy: 0.8978
# epoch  17 : setting learning rate to  0.16842105263157897
# Epoch 17/24
# 98/98 [==============================] - 46s 471ms/step - loss: 0.4759 - accuracy: 0.9051
# epoch  18 : setting learning rate to  0.1473684210526316
# Epoch 18/24
# 98/98 [==============================] - 46s 469ms/step - loss: 0.4479 - accuracy: 0.9149
# epoch  19 : setting learning rate to  0.12631578947368421
# Epoch 19/24
# 98/98 [==============================] - 46s 472ms/step - loss: 0.4292 - accuracy: 0.9204
# epoch  20 : setting learning rate to  0.10526315789473689
# Epoch 20/24
# 98/98 [==============================] - 46s 470ms/step - loss: 0.4070 - accuracy: 0.9267
# epoch  21 : setting learning rate to  0.08421052631578951
# Epoch 21/24
# 98/98 [==============================] - 46s 472ms/step - loss: 0.3805 - accuracy: 0.9355
# epoch  22 : setting learning rate to  0.06315789473684214
# Epoch 22/24
# 98/98 [==============================] - 46s 468ms/step - loss: 0.3640 - accuracy: 0.9397
# epoch  23 : setting learning rate to  0.04210526315789476
# Epoch 23/24
# 98/98 [==============================] - 46s 471ms/step - loss: 0.3361 - accuracy: 0.9486
# epoch  24 : setting learning rate to  0.02105263157894738
# Epoch 24/24
# 98/98 [==============================] - 46s 469ms/step - loss: 0.3180 - accuracy: 0.9548
# is_training False
# inside validation cycle
# ===============
#
# 20/20 [==============================] - 3s 133ms/step - loss: 0.3913 - accuracy: 0.9298
# val accuracy score at the end of training model type  4 [0.39125559777021407, 0.92978513]
# =========================================
#
# is_training True
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 32, 32, 64)   1728        input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 32, 32, 64)   256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 32, 64)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 32, 32, 128)  73728       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 32, 32, 128)  512         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 32, 32, 128)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 16, 16, 128)  0           activation_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 16, 16, 128)  147456      max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 16, 16, 128)  512         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 16, 16, 128)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 16, 16, 128)  147456      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 16, 16, 128)  512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 16, 16, 128)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_10 (TensorFlowO [(None, 16, 16, 128) 0           max_pooling2d_15[0][0]
#                                                                  activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 16, 16, 256)  294912      tf_op_layer_add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 16, 16, 256)  1024        conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 16, 16, 256)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 8, 8, 256)    0           activation_49[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 8, 8, 256)    0           max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 8, 8, 512)    1179648     lambda_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 8, 8, 512)    2048        conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 8, 8, 512)    0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 4, 4, 512)    0           activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 4, 4, 512)    2359296     max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 4, 4, 512)    2048        conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 4, 4, 512)    0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 4, 4, 512)    2359296     activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 4, 4, 512)    2048        conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 4, 4, 512)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_11 (TensorFlowO [(None, 4, 4, 512)]  0           max_pooling2d_17[0][0]
#                                                                  activation_52[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_5 (GlobalM (None, 512)          0           tf_op_layer_add_11[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 10)           5120        global_max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 10)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 10)           0           lambda_11[0][0]
# ==================================================================================================
# Total params: 6,577,600
# Trainable params: 6,573,120
# Non-trainable params: 4,480
# __________________________________________________________________________________________________
# Model will be trained with image augmentation in put layer
# ====================
# Model will also include distortion after Res Blk 2
# =======================
# Train for 98.0 steps
# epoch  1 : setting learning rate to  0.025
# Epoch 1/24
# is_training True
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f6840fcb598> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7f6840fcb598> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# is_training True
# 98/98 [==============================] - 48s 490ms/step - loss: 1.7398 - accuracy: 0.3992
# epoch  2 : setting learning rate to  0.1
# Epoch 2/24
# 98/98 [==============================] - 45s 460ms/step - loss: 1.3438 - accuracy: 0.5507
# epoch  3 : setting learning rate to  0.175
# Epoch 3/24
# 98/98 [==============================] - 45s 462ms/step - loss: 1.0708 - accuracy: 0.6597
# epoch  4 : setting learning rate to  0.24999999999999997
# Epoch 4/24
# 98/98 [==============================] - 45s 461ms/step - loss: 0.9423 - accuracy: 0.7150
# epoch  5 : setting learning rate to  0.325
# Epoch 5/24
# 98/98 [==============================] - 45s 461ms/step - loss: 0.9110 - accuracy: 0.7361
# epoch  6 : setting learning rate to  0.4
# Epoch 6/24
# 98/98 [==============================] - 45s 460ms/step - loss: 0.8612 - accuracy: 0.7627
# epoch  7 : setting learning rate to  0.37894736842105264
# Epoch 7/24
# 98/98 [==============================] - 45s 460ms/step - loss: 0.7576 - accuracy: 0.8066
# epoch  8 : setting learning rate to  0.35789473684210527
# Epoch 8/24
# 98/98 [==============================] - 45s 461ms/step - loss: 0.7143 - accuracy: 0.8216
# epoch  9 : setting learning rate to  0.33684210526315794
# Epoch 9/24
# 98/98 [==============================] - 45s 464ms/step - loss: 0.6824 - accuracy: 0.8361
# epoch  10 : setting learning rate to  0.31578947368421056
# Epoch 10/24
# 98/98 [==============================] - 45s 462ms/step - loss: 0.6308 - accuracy: 0.8534
# epoch  11 : setting learning rate to  0.2947368421052632
# Epoch 11/24
# 98/98 [==============================] - 45s 459ms/step - loss: 0.6070 - accuracy: 0.8635
# epoch  12 : setting learning rate to  0.2736842105263158
# Epoch 12/24
# 98/98 [==============================] - 45s 462ms/step - loss: 0.5915 - accuracy: 0.8690
# epoch  13 : setting learning rate to  0.25263157894736843
# Epoch 13/24
# 98/98 [==============================] - 45s 459ms/step - loss: 0.5668 - accuracy: 0.8781
# epoch  14 : setting learning rate to  0.23157894736842108
# Epoch 14/24
# 98/98 [==============================] - 45s 462ms/step - loss: 0.5510 - accuracy: 0.8830
# epoch  15 : setting learning rate to  0.2105263157894737
# Epoch 15/24
# 98/98 [==============================] - 45s 460ms/step - loss: 0.5118 - accuracy: 0.8963
# epoch  16 : setting learning rate to  0.18947368421052635
# Epoch 16/24
# 98/98 [==============================] - 45s 461ms/step - loss: 0.4996 - accuracy: 0.9003
# epoch  17 : setting learning rate to  0.16842105263157897
# Epoch 17/24
# 98/98 [==============================] - 45s 463ms/step - loss: 0.4721 - accuracy: 0.9078
# epoch  18 : setting learning rate to  0.1473684210526316
# Epoch 18/24
# 98/98 [==============================] - 45s 459ms/step - loss: 0.4483 - accuracy: 0.9138
# epoch  19 : setting learning rate to  0.12631578947368421
# Epoch 19/24
# 98/98 [==============================] - 45s 461ms/step - loss: 0.4282 - accuracy: 0.9211
# epoch  20 : setting learning rate to  0.10526315789473689
# Epoch 20/24
# 98/98 [==============================] - 45s 464ms/step - loss: 0.4032 - accuracy: 0.9290
# epoch  21 : setting learning rate to  0.08421052631578951
# Epoch 21/24
# 98/98 [==============================] - 45s 461ms/step - loss: 0.3750 - accuracy: 0.9381
# epoch  22 : setting learning rate to  0.06315789473684214
# Epoch 22/24
# 98/98 [==============================] - 45s 463ms/step - loss: 0.3557 - accuracy: 0.9432
# epoch  23 : setting learning rate to  0.04210526315789476
# Epoch 23/24
# 98/98 [==============================] - 45s 461ms/step - loss: 0.3358 - accuracy: 0.9495
# epoch  24 : setting learning rate to  0.02105263157894738
# Epoch 24/24
# 98/98 [==============================] - 45s 462ms/step - loss: 0.3156 - accuracy: 0.9554
# is_training False
# inside validation cycle
# ===============
#
# 20/20 [==============================] - 3s 133ms/step - loss: 0.3924 - accuracy: 0.9336
# val accuracy score at the end of training model type  5 [0.39241442531347276, 0.93359375]
# =========================================

# %% [markdown]
# ### Summary of Test Results
# Hyperparameters : Epochs:24, max_lr:0.4, momentum:0.9, L2-wt_decay on Conv Layers :1.25e-4

# %% [markdown]
# | Trial | Augmentation strategy | Train accuracy |Test Accuracy | Hyperparameters |Comments |
# | :--- | :---: | :---: | :---: | :---: | :--- |
# | 1 | cutout(flip_lr(pad4_random_crop(inp_image),8)  |97.69  | 93.31 | as above | train-test acc gap 4.38 |
# | 2 | cutout(flip_lr(pad2_random_crop(res_blk1),4)  |99.93  | 91.77 | " | Lower Val accuracy , Tendency to overfit . Perhaps try a more stringent Aug policy ? |
# | 3 | cutout(flip_lr(pad1_random_crop(res_blk2),2)  | 99.95 | 91.04 | " | Lowest Val Accuracy, Tendency to overfit. Try a more stringent aug policy? |
# | 4 | augmentation of trial 2 + augmentation of trial 3  | 99.60  | 91.61 | " | Lower Val Accuracy, Tendency to overfit. Try a more stringent aug policy? |
# | 5 | augmentations of trial 1 + augmentation of trial 2  | 95.48  | 92.98 |"| Better regularization: train-test acc gap 2.5 |
# | 5 | augmentations of trial 1 + augmentation of trial 3  | 95.54 | 93.36 |"| Better Regularization - Train-Test acc gap : 2.18 |

# %% [markdown]
# **Validation accuracy went down when only Distortion was used in the mid/lower layers (after Res Blk1 and Res Blk2 ) But when used in combination with usual Image augmentation , there seems to be better Regularization and perhaps we could explore such an option. If we were to pursue only Distortion of middle or lower layers (with a good enough size of channels ) , we may need to try more stringent augmentation strategies to overcome the problem of overfitting**
